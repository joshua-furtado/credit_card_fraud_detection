# %% [markdown]
# # Credit Card Fraud Detection
#
# The creditcard.csv dataset contains transactions made by credit cards, they are labeled as fraudulent or genuine. This is important for companies that have transaction systems to build a model for detecting fraudulent activities.
#
# Implement different algorithms like decision trees, logistic regression, and artificial neural networks to see which gives better accuracy. Compare the results of each algorithm and understand the behavior of models.

# %% [markdown]
# ## Import CSV file

# %%
# Import necessary libraries
import pandas as pd
import numpy as np

# %%
# Read creditcard CSV file into DataFrame
df = pd.read_csv("creditcard.csv")

# %% [markdown]
# ## The data at a glance

# %%
# Get dimensions
df.shape
# Out:
# (284807, 31)

# %%
# Get keys
df.keys()
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
# Use this to show all columns. Use pd.reset_option(“max_columns”) to reset to default.
pd.set_option('max_columns', None)

# %%
# Get first 5 rows
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
#         V15       V16       V17       V18       V19       V20       V21  \
# 0  1.468177 -0.470401  0.207971  0.025791  0.403993  0.251412 -0.018307
# 1  0.635558  0.463917 -0.114805 -0.183361 -0.145783 -0.069083 -0.225775
# 2  2.345865 -2.890083  1.109969 -0.121359 -2.261857  0.524980  0.247998
# 3 -0.631418 -1.059647 -0.684093  1.965775 -1.232622 -0.208038 -0.108300
# 4  0.175121 -0.451449 -0.237033 -0.038195  0.803487  0.408542 -0.009431
#
#         V22       V23       V24       V25       V26       V27       V28  \
# 0  0.277838 -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053
# 1 -0.638672  0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724
# 2  0.771679  0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752
# 3  0.005274 -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458
# 4  0.798278 -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153
#
#    Amount  Class
# 0  149.62      0
# 1    2.69      0
# 2  378.66      0
# 3  123.50      0
# 4   69.99      0

# %%
# Get last 5 rows
df.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9       V10       V11       V12  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  4.356170 -1.593105  2.711941
# 284803  1.058415  0.024330  0.294869  0.584800 -0.975926 -0.150189  0.915802
# 284804  3.031260 -0.296827  0.708417  0.432454 -0.484782  0.411614  0.063119
# 284805  0.623708 -0.686180  0.679145  0.392087 -0.399126 -1.933849 -0.962886
# 284806 -0.649617  1.577006 -0.414650  0.486180 -0.915427 -1.040458 -0.031513
#
#              V13       V14       V15       V16       V17       V18       V19  \
# 284802 -0.689256  4.626942 -0.924459  1.107641  1.991691  0.510632 -0.682920
# 284803  1.214756 -0.675143  1.164931 -0.711757 -0.025693 -1.221179 -1.545556
# 284804 -0.183699 -0.510602  1.329284  0.140716  0.313502  0.395652 -0.577252
# 284805 -1.042082  0.449624  1.962563 -0.608577  0.509928  1.113981  2.897849
# 284806 -0.188093 -0.084316  0.041333 -0.302620 -0.660377  0.167430 -0.256117
#
#              V20       V21       V22       V23       V24       V25       V26  \
# 284802  1.475829  0.213454  0.111864  1.014480 -0.509348  1.436807  0.250034
# 284803  0.059616  0.214205  0.924384  0.012463 -1.016226 -0.606624 -0.395255
# 284804  0.001396  0.232045  0.578229 -0.037501  0.640134  0.265745 -0.087371
# 284805  0.127434  0.265245  0.800049 -0.163298  0.123205 -0.569159  0.546668
# 284806  0.382948  0.261057  0.643078  0.376777  0.008797 -0.473649 -0.818267
#
#              V27       V28  Amount  Class
# 284802  0.943651  0.823731    0.77      0
# 284803  0.068472 -0.053527   24.79      0
# 284804  0.004455 -0.026561   67.88      0
# 284805  0.108821  0.104533   10.00      0
# 284806 -0.002415  0.013649  217.00      0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
# Time      284807 non-null float64
# V1        284807 non-null float64
# V2        284807 non-null float64
# V3        284807 non-null float64
# V4        284807 non-null float64
# V5        284807 non-null float64
# V6        284807 non-null float64
# V7        284807 non-null float64
# V8        284807 non-null float64
# V9        284807 non-null float64
# V10       284807 non-null float64
# V11       284807 non-null float64
# V12       284807 non-null float64
# V13       284807 non-null float64
# V14       284807 non-null float64
# V15       284807 non-null float64
# V16       284807 non-null float64
# V17       284807 non-null float64
# V18       284807 non-null float64
# V19       284807 non-null float64
# V20       284807 non-null float64
# V21       284807 non-null float64
# V22       284807 non-null float64
# V23       284807 non-null float64
# V24       284807 non-null float64
# V25       284807 non-null float64
# V26       284807 non-null float64
# V27       284807 non-null float64
# V28       284807 non-null float64
# Amount    284807 non-null float64
# Class     284807 non-null int64
# dtypes: float64(30), int64(1)
# memory usage: 67.4 MB

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.919560e-15  5.688174e-16 -8.769071e-15  2.782312e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552563e-15  2.010663e-15 -1.694249e-15 -1.927028e-16 -3.137024e-15
# std    1.380247e+00  1.332271e+00  1.237094e+00  1.194353e+00  1.098632e+00
# min   -1.137433e+02 -2.616051e+01 -4.355724e+01 -7.321672e+01 -1.343407e+01
# 25%   -6.915971e-01 -7.682956e-01 -5.540759e-01 -2.086297e-01 -6.430976e-01
# 50%   -5.433583e-02 -2.741871e-01  4.010308e-02  2.235804e-02 -5.142873e-02
# 75%    6.119264e-01  3.985649e-01  5.704361e-01  3.273459e-01  5.971390e-01
# max    3.480167e+01  7.330163e+01  1.205895e+02  2.000721e+01  1.559499e+01
#
#                 V10           V11           V12           V13           V14  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   1.768627e-15  9.170318e-16 -1.810658e-15  1.693438e-15  1.479045e-15
# std    1.088850e+00  1.020713e+00  9.992014e-01  9.952742e-01  9.585956e-01
# min   -2.458826e+01 -4.797473e+00 -1.868371e+01 -5.791881e+00 -1.921433e+01
# 25%   -5.354257e-01 -7.624942e-01 -4.055715e-01 -6.485393e-01 -4.255740e-01
# 50%   -9.291738e-02 -3.275735e-02  1.400326e-01 -1.356806e-02  5.060132e-02
# 75%    4.539234e-01  7.395934e-01  6.182380e-01  6.625050e-01  4.931498e-01
# max    2.374514e+01  1.201891e+01  7.848392e+00  7.126883e+00  1.052677e+01
#
#                 V15           V16           V17           V18           V19  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   3.482336e-15  1.392007e-15 -7.528491e-16  4.328772e-16  9.049732e-16
# std    9.153160e-01  8.762529e-01  8.493371e-01  8.381762e-01  8.140405e-01
# min   -4.498945e+00 -1.412985e+01 -2.516280e+01 -9.498746e+00 -7.213527e+00
# 25%   -5.828843e-01 -4.680368e-01 -4.837483e-01 -4.988498e-01 -4.562989e-01
# 50%    4.807155e-02  6.641332e-02 -6.567575e-02 -3.636312e-03  3.734823e-03
# 75%    6.488208e-01  5.232963e-01  3.996750e-01  5.008067e-01  4.589494e-01
# max    8.877742e+00  1.731511e+01  9.253526e+00  5.041069e+00  5.591971e+00
#
#                 V20           V21           V22           V23           V24  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   5.085503e-16  1.537294e-16  7.959909e-16  5.367590e-16  4.458112e-15
# std    7.709250e-01  7.345240e-01  7.257016e-01  6.244603e-01  6.056471e-01
# min   -5.449772e+01 -3.483038e+01 -1.093314e+01 -4.480774e+01 -2.836627e+00
# 25%   -2.117214e-01 -2.283949e-01 -5.423504e-01 -1.618463e-01 -3.545861e-01
# 50%   -6.248109e-02 -2.945017e-02  6.781943e-03 -1.119293e-02  4.097606e-02
# 75%    1.330408e-01  1.863772e-01  5.285536e-01  1.476421e-01  4.395266e-01
# max    3.942090e+01  2.720284e+01  1.050309e+01  2.252841e+01  4.584549e+00
#
#                 V25           V26           V27           V28         Amount  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  284807.000000
# mean   1.453003e-15  1.699104e-15 -3.660161e-16 -1.206049e-16      88.349619
# std    5.212781e-01  4.822270e-01  4.036325e-01  3.300833e-01     250.120109
# min   -1.029540e+01 -2.604551e+00 -2.256568e+01 -1.543008e+01       0.000000
# 25%   -3.171451e-01 -3.269839e-01 -7.083953e-02 -5.295979e-02       5.600000
# 50%    1.659350e-02 -5.213911e-02  1.342146e-03  1.124383e-02      22.000000
# 75%    3.507156e-01  2.409522e-01  9.104512e-02  7.827995e-02      77.165000
# max    7.519589e+00  3.517346e+00  3.161220e+01  3.384781e+01   25691.160000
#
#                Class
# count  284807.000000
# mean        0.001727
# std         0.041527
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000

# %%
# Check for null values
df.isnull().values.any()
# Out:
# False

# %% [markdown]
# ### Explore normal vs fraudulent transaction data

# %%
# Count number of normal(0) and fraudulent(1) transactions
df['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
# Plot 'Class' bar chart
import matplotlib.pyplot as plt

ax = df['Class'].value_counts().plot(kind='bar', figsize=(6,6))
ax_title = ax.set_title("Bar chart showing number of normal(0) and fraudulent(1) transactions.")
ax_xlabel = ax.set_xlabel('Class')
ax_ylabel = ax.set_ylabel('Number of transcations')
ax_xticklabels = ax.set_xticklabels(['Normal','Fraud'])

# %%
# Describe transcation amount
df['Amount'].describe()
# Out:
# count    284807.000000
# mean         88.349619
# std         250.120109
# min           0.000000
# 25%           5.600000
# 50%          22.000000
# 75%          77.165000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
# Transaction amount standard deviation
df['Amount'].std()
# Out:
# 250.1201092402221

# %%
# Transaction amount variance
df['Amount'].var()
# Out:
# 62560.069046340635

# %%
# Define normal and fraudulent transcation DataFrames
normal = df[df['Class']==0]
fraud = df[df['Class']==1]

# %%
# Describe normal transaction amount
normal.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
# Describe fraud transaction amount
fraud.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
# Plot histogram of amounts for normal and fraudulent transactions

ax = df['Amount'].hist(by=df['Class'], figsize=(14,6), bins=50, sharex=False, layout=(1,2))
ax[0].set_xlabel('Amount')
ax[0].set_ylabel('Frequency')
ax[0].set_title('Normal')
ax[1].set_xlabel('Amount')
ax[1].set_ylabel('Frequency')
ax[1].set_title('Fraud')
title = plt.suptitle('Histogram of amounts for normal and fraudulent transactions.')

# %%
# Scatter plot 'Amount vs. Time' for normal and fraudulent transactions

fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(14,6), sharey=False)
fig.suptitle('Scatter \'Amount vs. Time\' for normal and fraudulent transactions.')

normal.plot.scatter(x='Time', y='Amount', legend=False, ax=ax1)
ax1_title = ax1.set_title("Normal")

fraud.plot.scatter(x='Time', y='Amount', legend=False, ax=ax2)
ax2_title = ax2.set_title("Fraud")

# %% [markdown]
# ## Logistic regression

# %%
features = df.drop(['Class'], axis=1)
label = df['Class']
n_samples, n_features = features.shape

# %% [markdown]
# ### Split data into training and test sets

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(features, label, test_size = 0.3, random_state = 9)

# %% [markdown]
# ### Train the algorithm

# %%
from sklearn.linear_model import LogisticRegression

logistic_regressor = LogisticRegression()
logistic_regressor.fit(x_train, y_train)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %% [markdown]
# #### Training accuracy

# %%
logistic_regressor.score(x_train, y_train)
# Out:
# 0.998931602495937

# %% [markdown]
# ### Test model on test set

# %%
y_pred = logistic_regressor.predict(x_test)
results = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})

# %%
# Results for first 5 examples of the test set
results.head()
# Out:
#         Actual  Predicted
# 210658       0          0
# 4285         0          0
# 209292       0          0
# 184766       0          0
# 267219       0          0

# %%
from sklearn import metrics
print('Testing accuracy:', metrics.accuracy_score(y_test, y_pred))
# Out:
# Testing accuracy: 0.9987594068560327

# %%
# Classifiation report (https://www.scikit-yb.org/en/latest/api/classifier/classification_report.html)
from sklearn.metrics import classification_report , confusion_matrix
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85287
#            1       0.70      0.56      0.62       156
#
#     accuracy                           1.00     85443
#    macro avg       0.85      0.78      0.81     85443
# weighted avg       1.00      1.00      1.00     85443

# %%
actual_labels = ['actual_normal', 'actual_fraud']
pred_labels = ['predicted_normal', 'predicted_fraud']
matrix = confusion_matrix(y_test, y_pred)
matrix_df = pd.DataFrame(matrix, index=actual_labels, columns=pred_labels)
matrix_df
# Out:
#                predicted_normal  predicted_fraud
# actual_normal             85250               37
# actual_fraud                 69               87

# %%
import seaborn as sns

class_labels = ['normal', 'fraud']
matrix_df = pd.DataFrame(matrix, index=class_labels, columns=class_labels)
sns.heatmap(matrix_df, annot=True, cbar=None, cmap="Blues", fmt = 'd')
plt.title("Confusion Matrix"), plt.tight_layout()
plt.ylabel("True Class"), plt.xlabel("Predicted Class")
plt.show()

# %% [markdown]
# ## Decision Trees

# %% [markdown]
# ### Train the algorithm

# %%
from sklearn.tree import DecisionTreeClassifier

decision_tree = DecisionTreeClassifier()
decision_tree.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %% [markdown]
# #### Training accuracy

# %%
decision_tree.score(x_train, y_train)
# Out:
# 1.0

# %% [markdown]
# ### Test model on test set

# %%
y_pred = decision_tree.predict(x_test)
results = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})

# %%
# Results for first 5 examples of the test set
results.head()
# Out:
#         Actual  Predicted
# 210658       0          0
# 4285         0          0
# 209292       0          0
# 184766       0          0
# 267219       0          0

# %%
print('Testing accuracy:', metrics.accuracy_score(y_test, y_pred))
# Out:
# Testing accuracy: 0.9990988144142879

# %%
# Classifiation report (https://www.scikit-yb.org/en/latest/api/classifier/classification_report.html)
from sklearn.metrics import classification_report , confusion_matrix
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85287
#            1       0.76      0.74      0.75       156
#
#     accuracy                           1.00     85443
#    macro avg       0.88      0.87      0.88     85443
# weighted avg       1.00      1.00      1.00     85443

# %%
actual_labels = ['actual_normal', 'actual_fraud']
pred_labels = ['predicted_normal', 'predicted_fraud']
matrix = confusion_matrix(y_test, y_pred)
matrix_df = pd.DataFrame(matrix, index=actual_labels, columns=pred_labels)
matrix_df
# Out:
#                predicted_normal  predicted_fraud
# actual_normal             85250               37
# actual_fraud                 40              116

# %%
class_labels = ['normal', 'fraud']
matrix_df = pd.DataFrame(matrix, index=class_labels, columns=class_labels)
sns.heatmap(matrix_df, annot=True, cbar=None, cmap="Blues", fmt = 'd')
plt.title("Confusion Matrix"), plt.tight_layout()
plt.ylabel("True Class"), plt.xlabel("Predicted Class")
plt.show()

# %% [markdown]
# ### Decision Tree

# %%
from sklearn import tree

tree.plot_tree(decision_tree, filled=True, rounded=True)
# Out:
# [Text(118.25358715979628, 212.91, 'X[17] <= -2.704\nentropy = 0.003\nsamples = 199364\nvalue = [199028, 336]'),
#  Text(94.23921056819991, 203.85, 'X[12] <= -2.196\nentropy = 0.363\nsamples = 310\nvalue = [74, 236]'),
#  Text(77.07380550692345, 194.79, 'X[26] <= -0.225\nentropy = 0.289\nsamples = 285\nvalue = [50, 235]'),
#  Text(53.65610058889066, 185.73, 'X[27] <= 1.253\nentropy = 0.478\nsamples = 99\nvalue = [39, 60]'),
#  Text(40.924144516950506, 176.67, 'X[14] <= -3.176\nentropy = 0.357\nsamples = 73\nvalue = [17, 56]'),
#  Text(33.64874104727041, 167.60999999999999, 'X[4] <= -0.896\nentropy = 0.225\nsamples = 62\nvalue = [8, 54]'),
#  Text(30.01103931243037, 158.55, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(37.286442782110456, 158.55, 'X[13] <= 1.621\nentropy = 0.18\nsamples = 60\nvalue = [6, 54]'),
#  Text(27.282763011300336, 149.49, 'X[27] <= 1.175\nentropy = 0.131\nsamples = 57\nvalue = [4, 53]'),
#  Text(18.18850867420022, 140.43, 'X[19] <= 2.492\nentropy = 0.073\nsamples = 53\nvalue = [2, 51]'),
#  Text(10.913105204520134, 131.37, 'X[6] <= -3.535\nentropy = 0.039\nsamples = 50\nvalue = [1, 49]'),
#  Text(7.275403469680089, 122.30999999999999, 'X[14] <= -8.844\nentropy = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(3.6377017348400447, 113.24999999999999, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(10.913105204520134, 113.24999999999999, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(14.550806939360179, 122.30999999999999, 'entropy = 0.0\nsamples = 46\nvalue = [0, 46]'),
#  Text(25.463912143880314, 131.37, 'X[29] <= 59.945\nentropy = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(21.826210409040268, 122.30999999999999, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(29.101613878720357, 122.30999999999999, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(36.37701734840044, 140.43, 'X[18] <= -2.631\nentropy = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(32.7393156135604, 131.37, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(40.01471908324049, 131.37, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(47.29012255292058, 149.49, 'X[17] <= -3.082\nentropy = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(43.652420818080536, 140.43, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(50.92782428776063, 140.43, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(48.19954798663059, 167.60999999999999, 'X[16] <= -4.505\nentropy = 0.298\nsamples = 11\nvalue = [9, 2]'),
#  Text(44.56184625179055, 158.55, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(51.837249721470634, 158.55, 'entropy = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(66.38805666083081, 176.67, 'X[6] <= -4.023\nentropy = 0.26\nsamples = 26\nvalue = [22, 4]'),
#  Text(62.75035492599077, 167.60999999999999, 'X[8] <= 11.841\nentropy = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(59.11265319115073, 158.55, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(66.38805666083081, 158.55, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(70.02575839567086, 167.60999999999999, 'entropy = 0.0\nsamples = 20\nvalue = [20, 0]'),
#  Text(100.49151042495623, 185.73, 'X[10] <= -1.369\nentropy = 0.111\nsamples = 186\nvalue = [11, 175]'),
#  Text(89.1236925035811, 176.67, 'X[4] <= 1.185\nentropy = 0.084\nsamples = 182\nvalue = [8, 174]'),
#  Text(77.30116186535095, 167.60999999999999, 'X[13] <= 0.285\nentropy = 0.494\nsamples = 9\nvalue = [4, 5]'),
#  Text(73.6634601305109, 158.55, 'X[16] <= -2.327\nentropy = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(70.02575839567086, 149.49, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(77.30116186535095, 149.49, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(80.938863600191, 158.55, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(100.94622314181125, 167.60999999999999, 'X[28] <= 0.945\nentropy = 0.045\nsamples = 173\nvalue = [4, 169]'),
#  Text(91.85196880471113, 158.55, 'X[5] <= 0.476\nentropy = 0.024\nsamples = 166\nvalue = [2, 164]'),
#  Text(84.57656533503103, 149.49, 'X[13] <= -1.618\nentropy = 0.013\nsamples = 158\nvalue = [1, 157]'),
#  Text(80.938863600191, 140.43, 'X[15] <= 0.683\nentropy = 0.198\nsamples = 9\nvalue = [1, 8]'),
#  Text(77.30116186535095, 131.37, 'entropy = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(84.57656533503103, 131.37, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(88.21426706987108, 140.43, 'entropy = 0.0\nsamples = 149\nvalue = [0, 149]'),
#  Text(99.12737227439122, 149.49, 'X[5] <= 0.503\nentropy = 0.219\nsamples = 8\nvalue = [1, 7]'),
#  Text(95.48967053955117, 140.43, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(102.76507400923126, 140.43, 'entropy = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(110.04047747891136, 158.55, 'X[21] <= 1.515\nentropy = 0.408\nsamples = 7\nvalue = [2, 5]'),
#  Text(106.4027757440713, 149.49, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(113.67817921375139, 149.49, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(111.85932834633137, 176.67, 'X[28] <= 1.121\nentropy = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(108.22162661149133, 167.60999999999999, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(115.49703008117142, 167.60999999999999, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(111.40461562947637, 194.79, 'X[22] <= -1.765\nentropy = 0.077\nsamples = 25\nvalue = [24, 1]'),
#  Text(107.76691389463632, 185.73, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(115.04231736431642, 185.73, 'entropy = 0.0\nsamples = 24\nvalue = [24, 0]'),
#  Text(142.26796375139264, 203.85, 'X[14] <= -7.785\nentropy = 0.001\nsamples = 199054\nvalue = [198954, 100]'),
#  Text(125.95542256883655, 194.79, 'X[3] <= -3.967\nentropy = 0.252\nsamples = 27\nvalue = [4, 23]'),
#  Text(122.3177208339965, 185.73, 'entropy = 0.0\nsamples = 23\nvalue = [0, 23]'),
#  Text(129.5931243036766, 185.73, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(158.58050493394876, 194.79, 'X[14] <= -4.658\nentropy = 0.001\nsamples = 199027\nvalue = [198950, 77]'),
#  Text(136.86852777335667, 185.73, 'X[10] <= -1.841\nentropy = 0.236\nsamples = 161\nvalue = [139, 22]'),
#  Text(129.5931243036766, 176.67, 'X[24] <= -1.045\nentropy = 0.444\nsamples = 30\nvalue = [10, 20]'),
#  Text(125.95542256883655, 167.60999999999999, 'entropy = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(133.23082603851662, 167.60999999999999, 'X[1] <= 1.211\nentropy = 0.165\nsamples = 22\nvalue = [2, 20]'),
#  Text(129.5931243036766, 158.55, 'entropy = 0.0\nsamples = 20\nvalue = [0, 20]'),
#  Text(136.86852777335667, 158.55, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(144.14393124303677, 176.67, 'X[21] <= -0.046\nentropy = 0.03\nsamples = 131\nvalue = [129, 2]'),
#  Text(140.50622950819672, 167.60999999999999, 'entropy = 0.0\nsamples = 124\nvalue = [124, 0]'),
#  Text(147.78163297787682, 167.60999999999999, 'X[4] <= 4.525\nentropy = 0.408\nsamples = 7\nvalue = [5, 2]'),
#  Text(144.14393124303677, 158.55, 'entropy = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(151.41933471271685, 158.55, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(180.29248209454082, 185.73, 'X[12] <= -4.927\nentropy = 0.001\nsamples = 198866\nvalue = [198811, 55]'),
#  Text(158.69473818239695, 176.67, 'X[11] <= 3.889\nentropy = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(155.0570364475569, 167.60999999999999, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(162.332439917237, 167.60999999999999, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(201.8902260066847, 176.67, 'X[14] <= -4.243\nentropy = 0.001\nsamples = 198864\nvalue = [198810, 54]'),
#  Text(169.6078433869171, 167.60999999999999, 'X[7] <= 0.236\nentropy = 0.088\nsamples = 87\nvalue = [83, 4]'),
#  Text(165.97014165207705, 158.55, 'X[23] <= 0.262\nentropy = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(162.332439917237, 149.49, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(169.6078433869171, 149.49, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(173.24554512175712, 158.55, 'entropy = 0.0\nsamples = 81\nvalue = [81, 0]'),
#  Text(234.17260862645233, 167.60999999999999, 'X[4] <= 2.486\nentropy = 0.001\nsamples = 198777\nvalue = [198727, 50]'),
#  Text(195.95453764125418, 158.55, 'X[7] <= 3.79\nentropy = 0.0\nsamples = 188426\nvalue = [188398, 28]'),
#  Text(176.88324685659717, 149.49, 'X[29] <= 2122.555\nentropy = 0.0\nsamples = 187707\nvalue = [187682, 25]'),
#  Text(160.56687569632342, 140.43, 'X[20] <= -4.124\nentropy = 0.0\nsamples = 187574\nvalue = [187550, 24]'),
#  Text(138.84723858029605, 131.37, 'X[20] <= -4.137\nentropy = 0.01\nsamples = 203\nvalue = [202, 1]'),
#  Text(135.209536845456, 122.30999999999999, 'entropy = 0.0\nsamples = 202\nvalue = [202, 0]'),
#  Text(142.48494031513607, 122.30999999999999, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(182.2865128123508, 131.37, 'X[22] <= 2.151\nentropy = 0.0\nsamples = 187371\nvalue = [187348, 23]'),
#  Text(149.76034378481617, 122.30999999999999, 'X[14] <= -1.044\nentropy = 0.0\nsamples = 187174\nvalue = [187152, 22]'),
#  Text(95.62111093426708, 113.24999999999999, 'X[14] <= -1.044\nentropy = 0.001\nsamples = 16932\nvalue = [16922, 10]'),
#  Text(91.98340919942703, 104.19, 'X[0] <= 491.0\nentropy = 0.001\nsamples = 16931\nvalue = [16922, 9]'),
#  Text(79.25145312748687, 95.13, 'X[29] <= 470.44\nentropy = 0.062\nsamples = 31\nvalue = [30, 1]'),
#  Text(75.61375139264683, 86.07, 'entropy = 0.0\nsamples = 30\nvalue = [30, 0]'),
#  Text(82.88915486232692, 86.07, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(104.71536527136719, 95.13, 'X[29] <= 98.005\nentropy = 0.001\nsamples = 16900\nvalue = [16892, 8]'),
#  Text(90.164558332007, 86.07, 'X[0] <= 170346.0\nentropy = 0.0\nsamples = 13742\nvalue = [13740, 2]'),
#  Text(82.88915486232692, 77.00999999999999, 'X[1] <= 2.132\nentropy = 0.0\nsamples = 13512\nvalue = [13511, 1]'),
#  Text(79.25145312748687, 67.94999999999999, 'entropy = 0.0\nsamples = 13188\nvalue = [13188, 0]'),
#  Text(86.52685659716695, 67.94999999999999, 'X[1] <= 2.132\nentropy = 0.006\nsamples = 324\nvalue = [323, 1]'),
#  Text(82.88915486232692, 58.889999999999986, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(90.164558332007, 58.889999999999986, 'entropy = 0.0\nsamples = 323\nvalue = [323, 0]'),
#  Text(97.43996180168709, 77.00999999999999, 'X[0] <= 170349.0\nentropy = 0.009\nsamples = 230\nvalue = [229, 1]'),
#  Text(93.80226006684705, 67.94999999999999, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(101.07766353652714, 67.94999999999999, 'entropy = 0.0\nsamples = 229\nvalue = [229, 0]'),
#  Text(119.26617221072736, 86.07, 'X[29] <= 98.025\nentropy = 0.004\nsamples = 3158\nvalue = [3152, 6]'),
#  Text(111.99076874104728, 77.00999999999999, 'X[10] <= 0.08\nentropy = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(108.35306700620723, 67.94999999999999, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(115.62847047588731, 67.94999999999999, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(126.54157568040745, 77.00999999999999, 'X[10] <= -0.793\nentropy = 0.003\nsamples = 3156\nvalue = [3151, 5]'),
#  Text(122.90387394556741, 67.94999999999999, 'X[10] <= -0.793\nentropy = 0.008\nsamples = 1237\nvalue = [1232, 5]'),
#  Text(119.26617221072736, 58.889999999999986, 'X[1] <= 1.861\nentropy = 0.006\nsamples = 1236\nvalue = [1232, 4]'),
#  Text(109.26249243991724, 49.829999999999984, 'X[14] <= -1.075\nentropy = 0.005\nsamples = 1227\nvalue = [1224, 3]'),
#  Text(100.16823810281713, 40.76999999999998, 'X[13] <= 1.107\nentropy = 0.003\nsamples = 1176\nvalue = [1174, 2]'),
#  Text(92.89283463313704, 31.70999999999998, 'X[6] <= -1.43\nentropy = 0.002\nsamples = 1116\nvalue = [1115, 1]'),
#  Text(89.25513289829699, 22.649999999999977, 'X[6] <= -1.432\nentropy = 0.023\nsamples = 87\nvalue = [86, 1]'),
#  Text(85.61743116345696, 13.589999999999975, 'entropy = 0.0\nsamples = 86\nvalue = [86, 0]'),
#  Text(92.89283463313704, 13.589999999999975, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(96.53053636797708, 22.649999999999977, 'entropy = 0.0\nsamples = 1029\nvalue = [1029, 0]'),
#  Text(107.44364157249721, 31.70999999999998, 'X[13] <= 1.122\nentropy = 0.033\nsamples = 60\nvalue = [59, 1]'),
#  Text(103.80593983765718, 22.649999999999977, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(111.08134330733726, 22.649999999999977, 'entropy = 0.0\nsamples = 59\nvalue = [59, 0]'),
#  Text(118.35674677701735, 40.76999999999998, 'X[14] <= -1.075\nentropy = 0.038\nsamples = 51\nvalue = [50, 1]'),
#  Text(114.71904504217731, 31.70999999999998, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(121.9944485118574, 31.70999999999998, 'entropy = 0.0\nsamples = 50\nvalue = [50, 0]'),
#  Text(129.2698519815375, 49.829999999999984, 'X[12] <= 0.86\nentropy = 0.198\nsamples = 9\nvalue = [8, 1]'),
#  Text(125.63215024669744, 40.76999999999998, 'entropy = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(132.90755371637752, 40.76999999999998, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(126.54157568040745, 58.889999999999986, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(130.1792774152475, 67.94999999999999, 'entropy = 0.0\nsamples = 1919\nvalue = [1919, 0]'),
#  Text(99.25881266910712, 104.19, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(203.89957663536526, 113.24999999999999, 'X[23] <= 0.778\nentropy = 0.0\nsamples = 170242\nvalue = [170230, 12]'),
#  Text(191.224459653032, 104.19, 'X[15] <= 2.206\nentropy = 0.0\nsamples = 166545\nvalue = [166536, 9]'),
#  Text(180.4250326277256, 95.13, 'X[29] <= 1096.81\nentropy = 0.0\nsamples = 165954\nvalue = [165946, 8]'),
#  Text(169.739283781633, 86.07, 'X[19] <= 2.502\nentropy = 0.0\nsamples = 165209\nvalue = [165202, 7]'),
#  Text(159.28089129396784, 77.00999999999999, 'X[26] <= 1.246\nentropy = 0.0\nsamples = 164165\nvalue = [164159, 6]'),
#  Text(149.27721152315772, 67.94999999999999, 'X[17] <= 0.565\nentropy = 0.0\nsamples = 163093\nvalue = [163088, 5]'),
#  Text(140.18295718605762, 58.889999999999986, 'X[13] <= 1.575\nentropy = 0.0\nsamples = 140864\nvalue = [140863, 1]'),
#  Text(136.54525545121757, 49.829999999999984, 'entropy = 0.0\nsamples = 134526\nvalue = [134526, 0]'),
#  Text(143.82065892089767, 49.829999999999984, 'X[13] <= 1.575\nentropy = 0.0\nsamples = 6338\nvalue = [6337, 1]'),
#  Text(140.18295718605762, 40.76999999999998, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(147.45836065573772, 40.76999999999998, 'entropy = 0.0\nsamples = 6337\nvalue = [6337, 0]'),
#  Text(158.37146586025784, 58.889999999999986, 'X[17] <= 0.565\nentropy = 0.0\nsamples = 22229\nvalue = [22225, 4]'),
#  Text(154.7337641254178, 49.829999999999984, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(162.0091675950979, 49.829999999999984, 'X[17] <= 0.57\nentropy = 0.0\nsamples = 22228\nvalue = [22225, 3]'),
#  Text(154.7337641254178, 40.76999999999998, 'X[17] <= 0.57\nentropy = 0.007\nsamples = 286\nvalue = [285, 1]'),
#  Text(151.09606239057774, 31.70999999999998, 'entropy = 0.0\nsamples = 285\nvalue = [285, 0]'),
#  Text(158.37146586025784, 31.70999999999998, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(169.28457106477796, 40.76999999999998, 'X[5] <= 0.819\nentropy = 0.0\nsamples = 21942\nvalue = [21940, 2]'),
#  Text(165.64686932993794, 31.70999999999998, 'entropy = 0.0\nsamples = 18231\nvalue = [18231, 0]'),
#  Text(172.922272799618, 31.70999999999998, 'X[5] <= 0.82\nentropy = 0.001\nsamples = 3711\nvalue = [3709, 2]'),
#  Text(169.28457106477796, 22.649999999999977, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(176.55997453445806, 22.649999999999977, 'X[5] <= 0.868\nentropy = 0.001\nsamples = 3710\nvalue = [3709, 1]'),
#  Text(172.922272799618, 13.589999999999975, 'X[5] <= 0.868\nentropy = 0.01\nsamples = 197\nvalue = [196, 1]'),
#  Text(169.28457106477796, 4.529999999999973, 'entropy = 0.0\nsamples = 196\nvalue = [196, 0]'),
#  Text(176.55997453445806, 4.529999999999973, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(180.1976762692981, 13.589999999999975, 'entropy = 0.0\nsamples = 3513\nvalue = [3513, 0]'),
#  Text(169.28457106477796, 67.94999999999999, 'X[26] <= 1.247\nentropy = 0.002\nsamples = 1072\nvalue = [1071, 1]'),
#  Text(165.64686932993794, 58.889999999999986, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(172.922272799618, 58.889999999999986, 'entropy = 0.0\nsamples = 1071\nvalue = [1071, 0]'),
#  Text(180.1976762692981, 77.00999999999999, 'X[19] <= 2.502\nentropy = 0.002\nsamples = 1044\nvalue = [1043, 1]'),
#  Text(176.55997453445806, 67.94999999999999, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(183.83537800413816, 67.94999999999999, 'entropy = 0.0\nsamples = 1043\nvalue = [1043, 0]'),
#  Text(191.11078147381824, 86.07, 'X[29] <= 1097.045\nentropy = 0.003\nsamples = 745\nvalue = [744, 1]'),
#  Text(187.4730797389782, 77.00999999999999, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(194.74848320865829, 77.00999999999999, 'entropy = 0.0\nsamples = 744\nvalue = [744, 0]'),
#  Text(202.02388667833839, 95.13, 'X[15] <= 2.207\nentropy = 0.003\nsamples = 591\nvalue = [590, 1]'),
#  Text(198.38618494349834, 86.07, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(205.66158841317844, 86.07, 'entropy = 0.0\nsamples = 590\nvalue = [590, 0]'),
#  Text(216.57469361769856, 104.19, 'X[23] <= 0.778\nentropy = 0.002\nsamples = 3697\nvalue = [3694, 3]'),
#  Text(212.9369918828585, 95.13, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(220.2123953525386, 95.13, 'X[13] <= -2.135\nentropy = 0.001\nsamples = 3696\nvalue = [3694, 2]'),
#  Text(212.9369918828585, 86.07, 'X[13] <= -2.14\nentropy = 0.044\nsamples = 44\nvalue = [43, 1]'),
#  Text(209.29929014801846, 77.00999999999999, 'entropy = 0.0\nsamples = 43\nvalue = [43, 0]'),
#  Text(216.57469361769856, 77.00999999999999, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(227.48779882221868, 86.07, 'X[13] <= -1.521\nentropy = 0.001\nsamples = 3652\nvalue = [3651, 1]'),
#  Text(223.85009708737866, 77.00999999999999, 'X[13] <= -1.522\nentropy = 0.013\nsamples = 154\nvalue = [153, 1]'),
#  Text(220.2123953525386, 67.94999999999999, 'entropy = 0.0\nsamples = 153\nvalue = [153, 0]'),
#  Text(227.48779882221868, 67.94999999999999, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(231.12550055705873, 77.00999999999999, 'entropy = 0.0\nsamples = 3498\nvalue = [3498, 0]'),
#  Text(214.8126818398854, 122.30999999999999, 'X[21] <= 1.315\nentropy = 0.01\nsamples = 197\nvalue = [196, 1]'),
#  Text(211.17498010504536, 113.24999999999999, 'entropy = 0.0\nsamples = 196\nvalue = [196, 0]'),
#  Text(218.45038357472546, 113.24999999999999, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(193.19961801687091, 140.43, 'X[29] <= 2127.14\nentropy = 0.015\nsamples = 133\nvalue = [132, 1]'),
#  Text(189.5619162820309, 131.37, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(196.83731975171096, 131.37, 'entropy = 0.0\nsamples = 132\nvalue = [132, 0]'),
#  Text(215.0258284259112, 149.49, 'X[7] <= 3.792\nentropy = 0.008\nsamples = 719\nvalue = [716, 3]'),
#  Text(207.75042495623111, 140.43, 'X[5] <= -0.588\nentropy = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(204.11272322139106, 131.37, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(211.38812669107114, 131.37, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(222.3012318955913, 140.43, 'X[17] <= 1.751\nentropy = 0.003\nsamples = 716\nvalue = [715, 1]'),
#  Text(218.66353016075124, 131.37, 'entropy = 0.0\nsamples = 709\nvalue = [709, 0]'),
#  Text(225.93893363043134, 131.37, 'X[7] <= 4.039\nentropy = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(222.3012318955913, 122.30999999999999, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(229.5766353652714, 122.30999999999999, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(272.3906796116505, 158.55, 'X[4] <= 2.486\nentropy = 0.004\nsamples = 10351\nvalue = [10329, 22]'),
#  Text(268.75297787681046, 149.49, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(276.02838134649056, 149.49, 'X[14] <= -1.631\nentropy = 0.004\nsamples = 10350\nvalue = [10329, 21]'),
#  Text(251.13286009867898, 140.43, 'X[14] <= -1.635\nentropy = 0.036\nsamples = 433\nvalue = [425, 8]'),
#  Text(247.49515836383893, 131.37, 'X[1] <= 0.464\nentropy = 0.032\nsamples = 432\nvalue = [425, 7]'),
#  Text(243.8574566289989, 122.30999999999999, 'entropy = 0.0\nsamples = 279\nvalue = [279, 0]'),
#  Text(251.13286009867898, 122.30999999999999, 'X[2] <= -1.148\nentropy = 0.087\nsamples = 153\nvalue = [146, 7]'),
#  Text(247.49515836383893, 113.24999999999999, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(254.77056183351903, 113.24999999999999, 'X[5] <= -0.553\nentropy = 0.076\nsamples = 152\nvalue = [146, 6]'),
#  Text(251.13286009867898, 104.19, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(258.4082635683591, 104.19, 'X[22] <= 0.68\nentropy = 0.064\nsamples = 151\nvalue = [146, 5]'),
#  Text(254.77056183351903, 95.13, 'X[11] <= 1.675\nentropy = 0.052\nsamples = 150\nvalue = [146, 4]'),
#  Text(245.67630749641893, 86.07, 'X[17] <= 0.718\nentropy = 0.027\nsamples = 144\nvalue = [142, 2]'),
#  Text(238.40090402673883, 77.00999999999999, 'X[17] <= 0.557\nentropy = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(234.76320229189878, 67.94999999999999, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(242.03860576157888, 67.94999999999999, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(252.951710966099, 77.00999999999999, 'X[15] <= -1.654\nentropy = 0.014\nsamples = 139\nvalue = [138, 1]'),
#  Text(249.31400923125895, 67.94999999999999, 'X[11] <= 1.445\nentropy = 0.18\nsamples = 10\nvalue = [9, 1]'),
#  Text(245.67630749641893, 58.889999999999986, 'entropy = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(252.951710966099, 58.889999999999986, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(256.589412700939, 67.94999999999999, 'entropy = 0.0\nsamples = 129\nvalue = [129, 0]'),
#  Text(263.8648161706191, 86.07, 'X[17] <= 1.976\nentropy = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(260.2271144357791, 77.00999999999999, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(267.5025179054592, 77.00999999999999, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(262.0459653031991, 95.13, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(254.77056183351903, 131.37, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(300.9239025943021, 140.43, 'X[17] <= -2.025\nentropy = 0.003\nsamples = 9917\nvalue = [9904, 13]'),
#  Text(288.4193028807894, 131.37, 'X[4] <= 2.741\nentropy = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(284.7816011459494, 122.30999999999999, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(292.05700461562947, 122.30999999999999, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(313.42850230781477, 131.37, 'X[26] <= 2.736\nentropy = 0.002\nsamples = 9914\nvalue = [9902, 12]'),
#  Text(299.33240808530957, 122.30999999999999, 'X[4] <= 5.153\nentropy = 0.002\nsamples = 9906\nvalue = [9895, 11]'),
#  Text(282.0533248448194, 113.24999999999999, 'X[27] <= -2.508\nentropy = 0.002\nsamples = 9700\nvalue = [9692, 8]'),
#  Text(272.9590705077193, 104.19, 'X[16] <= -0.729\nentropy = 0.061\nsamples = 32\nvalue = [31, 1]'),
#  Text(269.3213687728792, 95.13, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(276.59677224255927, 95.13, 'entropy = 0.0\nsamples = 31\nvalue = [31, 0]'),
#  Text(291.14757918191947, 104.19, 'X[17] <= 1.675\nentropy = 0.001\nsamples = 9668\nvalue = [9661, 7]'),
#  Text(283.87217571223937, 95.13, 'X[15] <= -1.194\nentropy = 0.001\nsamples = 9521\nvalue = [9516, 5]'),
#  Text(280.2344739773993, 86.07, 'X[15] <= -1.195\nentropy = 0.004\nsamples = 2579\nvalue = [2574, 5]'),
#  Text(276.59677224255927, 77.00999999999999, 'X[19] <= -1.489\nentropy = 0.003\nsamples = 2578\nvalue = [2574, 4]'),
#  Text(272.9590705077193, 67.94999999999999, 'X[19] <= -1.49\nentropy = 0.018\nsamples = 438\nvalue = [434, 4]'),
#  Text(269.3213687728792, 58.889999999999986, 'X[17] <= 0.746\nentropy = 0.014\nsamples = 437\nvalue = [434, 3]'),
#  Text(260.2271144357791, 49.829999999999984, 'X[1] <= 1.933\nentropy = 0.009\nsamples = 423\nvalue = [421, 2]'),
#  Text(252.951710966099, 40.76999999999998, 'X[28] <= -0.307\nentropy = 0.005\nsamples = 407\nvalue = [406, 1]'),
#  Text(249.31400923125895, 31.70999999999998, 'X[28] <= -0.339\nentropy = 0.1\nsamples = 19\nvalue = [18, 1]'),
#  Text(245.67630749641893, 22.649999999999977, 'entropy = 0.0\nsamples = 18\nvalue = [18, 0]'),
#  Text(252.951710966099, 22.649999999999977, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(256.589412700939, 31.70999999999998, 'entropy = 0.0\nsamples = 388\nvalue = [388, 0]'),
#  Text(267.5025179054592, 40.76999999999998, 'X[24] <= -0.215\nentropy = 0.117\nsamples = 16\nvalue = [15, 1]'),
#  Text(263.8648161706191, 31.70999999999998, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(271.1402196402992, 31.70999999999998, 'entropy = 0.0\nsamples = 15\nvalue = [15, 0]'),
#  Text(278.4156231099793, 49.829999999999984, 'X[17] <= 0.761\nentropy = 0.133\nsamples = 14\nvalue = [13, 1]'),
#  Text(274.7779213751393, 40.76999999999998, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(282.0533248448194, 40.76999999999998, 'entropy = 0.0\nsamples = 13\nvalue = [13, 0]'),
#  Text(276.59677224255927, 58.889999999999986, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(280.2344739773993, 67.94999999999999, 'entropy = 0.0\nsamples = 2140\nvalue = [2140, 0]'),
#  Text(283.87217571223937, 77.00999999999999, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(287.5098774470794, 86.07, 'entropy = 0.0\nsamples = 6942\nvalue = [6942, 0]'),
#  Text(298.42298265159957, 95.13, 'X[17] <= 1.68\nentropy = 0.027\nsamples = 147\nvalue = [145, 2]'),
#  Text(294.7852809167595, 86.07, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(302.0606843864396, 86.07, 'X[17] <= 1.708\nentropy = 0.014\nsamples = 146\nvalue = [145, 1]'),
#  Text(298.42298265159957, 77.00999999999999, 'X[22] <= -0.82\nentropy = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(294.7852809167595, 67.94999999999999, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(302.0606843864396, 67.94999999999999, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(305.69838612127967, 77.00999999999999, 'entropy = 0.0\nsamples = 139\nvalue = [139, 0]'),
#  Text(316.61149132579976, 113.24999999999999, 'X[4] <= 5.154\nentropy = 0.029\nsamples = 206\nvalue = [203, 3]'),
#  Text(312.97378959095977, 104.19, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(320.2491930606398, 104.19, 'X[29] <= 0.03\nentropy = 0.019\nsamples = 205\nvalue = [203, 2]'),
#  Text(312.97378959095977, 95.13, 'X[10] <= 2.258\nentropy = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(309.3360878561197, 86.07, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(316.61149132579976, 86.07, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(327.5245965303199, 95.13, 'X[12] <= -2.832\nentropy = 0.01\nsamples = 198\nvalue = [197, 1]'),
#  Text(323.88689479547986, 86.07, 'X[13] <= 2.309\nentropy = 0.198\nsamples = 9\nvalue = [8, 1]'),
#  Text(320.2491930606398, 77.00999999999999, 'entropy = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(327.5245965303199, 77.00999999999999, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(331.16229826515996, 86.07, 'entropy = 0.0\nsamples = 189\nvalue = [189, 0]'),
#  Text(327.5245965303199, 122.30999999999999, 'X[26] <= 2.755\nentropy = 0.219\nsamples = 8\nvalue = [7, 1]'),
#  Text(323.88689479547986, 113.24999999999999, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(331.16229826515996, 113.24999999999999, 'entropy = 0.0\nsamples = 7\nvalue = [7, 0]')]

# %%
# Save tree in 'fraud_detection.pdf' file
import graphviz

dot_data = tree.export_graphviz(decision_tree, filled=True, rounded=True, special_characters=True, out_file=None) 
graph = graphviz.Source(dot_data) 
graph.render("fraud_detection")
# Out:
# 'fraud_detection.pdf'

# %% [markdown]
# ## Artificial neural network

# %% [markdown]
# ### Prepare data

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(features, label, test_size = 0.3, random_state = 9)

# %%
# Scale features to have 0 mean and unit variance (recommended for logistic regression)
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
# Convert features to torch tensors
import torch

x_train = torch.from_numpy(x_train.astype(np.float32))
x_test = torch.from_numpy(x_test.astype(np.float32))
y_train = torch.from_numpy(y_train.astype(np.float32).to_numpy())
y_test = torch.from_numpy(y_test.astype(np.float32).to_numpy())

# %%
# Reshape y tensors
y_train = y_train.view(y_train.shape[0], 1)
y_test = y_test.view(y_test.shape[0], 1)

# %% [markdown]
# ### Model

# %%
import torch.nn as nn

# Linear model f = wx + b , sigmoid at the end
class Model(nn.Module):
    def __init__(self, n_input_features):
        super(Model, self).__init__()
        self.linear = nn.Linear(n_input_features, 1) # 1 output feature

    def forward(self, x):
        y_pred = torch.sigmoid(self.linear(x))
        return y_pred
    
model = Model(n_features)

# %% [markdown]
# ### Loss and optimizer

# %%
num_epochs = 400
learning_rate = 0.1
criterion = nn.BCELoss() # Binary Cross Entropy Loss
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate) # Use Stochastic Gradient Descent

# %% [markdown]
# ### Training loop

# %%
for epoch in range(num_epochs):
    # Forward pass and loss calculation
    y_pred = model(x_train)
    loss = criterion(y_pred, y_train)

    # Backward pass
    loss.backward()
    
    # Update weights
    optimizer.step()

    # Zero gradients before new step
    optimizer.zero_grad()

    # Print loss every 10th epoch
    if (epoch+1) % 10 == 0:
        print(f'epoch: {epoch+1}, loss = {loss.item():.4f}')
# Out:
# epoch: 10, loss = 0.5388
# epoch: 20, loss = 0.3984
# epoch: 30, loss = 0.3088
# epoch: 40, loss = 0.2489
# epoch: 50, loss = 0.2070
# epoch: 60, loss = 0.1764
# epoch: 70, loss = 0.1534
# epoch: 80, loss = 0.1355
# epoch: 90, loss = 0.1212
# epoch: 100, loss = 0.1096
# epoch: 110, loss = 0.1000
# epoch: 120, loss = 0.0919
# epoch: 130, loss = 0.0850
# epoch: 140, loss = 0.0791
# epoch: 150, loss = 0.0740
# epoch: 160, loss = 0.0695
# epoch: 170, loss = 0.0655
# epoch: 180, loss = 0.0620
# epoch: 190, loss = 0.0588
# epoch: 200, loss = 0.0560
# epoch: 210, loss = 0.0534
# epoch: 220, loss = 0.0511
# epoch: 230, loss = 0.0489
# epoch: 240, loss = 0.0470
# epoch: 250, loss = 0.0452
# epoch: 260, loss = 0.0435
# epoch: 270, loss = 0.0420
# epoch: 280, loss = 0.0405
# epoch: 290, loss = 0.0392
# epoch: 300, loss = 0.0380
# epoch: 310, loss = 0.0368
# epoch: 320, loss = 0.0357
# epoch: 330, loss = 0.0347
# epoch: 340, loss = 0.0338
# epoch: 350, loss = 0.0329
# epoch: 360, loss = 0.0320
# epoch: 370, loss = 0.0312
# epoch: 380, loss = 0.0305
# epoch: 390, loss = 0.0298
# epoch: 400, loss = 0.0291

# %% [markdown]
# ### Test

# %%
with torch.no_grad():
    y_pred = model(x_test)
    y_pred_cls = y_predicted.round()
    acc = y_pred_cls.eq(y_test).sum().item() / y_test.shape[0]
    print(f'accuracy: {acc:.4f}')
# Out:
# accuracy: 0.9989
